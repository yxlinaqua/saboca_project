# %% [markdown]
# # Simple check on 1D radiative modeling (radmc3)
# 1. Considering a central star of 10 M$_{\odot}$, 5 R$_{\odot}$, 8000 K, a power-law density ditribution (-2) of envelope structure of the core (2000 AU-0.1 pc), no ISRF.
#
# Temperature profile is shown in left figure.
# Envelope density 10$^{6}$ cm$^{3}$-10$^{4}$ cm$^{3}$.

# %%
# %run plot_session_internal.py
# Out:
# Reading dust temperature

# %% [markdown]
# A solar-like star.

# %%
# %run plot_session_internal.py
# Out:
# Reading dust temperature

# %% [markdown]
# 2. Include ISRF model and no internal heating, with a central flattened density profile.
# (Dapp & Basu 2013?)
